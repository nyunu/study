# %% [markdown]
# # 1차_ 인구수로 자르기

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\82108\\Code_data\\people_1.csv")
df.head()
# Out:
#    행정구역(시군구)별        2021
# 0  행정구역(시군구)별    총인구수 (명)
# 1         경기도  13,565,450
# 2      　　　수원시   1,183,714
# 3      　　　성남시     930,948
# 4     　　　의정부시     463,661

# %%
df = df.loc[1:]
df
# Out:
#     행정구역(시군구)별        2021
# 1          경기도  13,565,450
# 2       　　　수원시   1,183,714
# 3       　　　성남시     930,948
# 4      　　　의정부시     463,661
# 5       　　　안양시     547,178
# 6       　　　부천시     806,067
# 7       　　　광명시     292,893
# 8       　　　평택시     564,288
# 9      　　　동두천시      93,592
# 10      　　　안산시     652,726
# 11      　　　고양시   1,079,353
# 12      　　　과천시      73,345
# 13      　　　구리시     191,948
# 14     　　　남양주시     733,798
# 15      　　　오산시     229,983
# 16      　　　시흥시     512,030
# 17      　　　군포시     268,535
# 18      　　　의왕시     163,356
# 19      　　　하남시     320,087
# 20      　　　용인시   1,077,508
# 21      　　　파주시     483,245
# 22      　　　이천시     223,177
# 23      　　　안성시     189,534
# 24      　　　김포시     486,508
# 25      　　　화성시     887,015
# 26      　　　광주시     387,289
# 27      　　　양주시     236,368
# 28      　　　포천시     148,939
# 29      　　　여주시     112,150
# 30      　　　연천군      42,721
# 31      　　　가평군      62,264
# 32      　　　양평군     121,230
# 33         강원도   1,538,492
# 34      　　　춘천시     284,594
# 35      　　　원주시     357,757
# 36      　　　강릉시     212,965
# 37      　　　동해시      90,081
# 38      　　　태백시      40,844
# 39      　　　속초시      82,791
# 40      　　　삼척시      63,429
# 41      　　　홍천군      68,365
# 42      　　　횡성군      46,481
# 43      　　　영월군      37,904
# 44      　　　평창군      40,996
# 45      　　　정선군      35,675
# 46      　　　철원군      43,340
# 47      　　　화천군      24,195
# 48      　　　양구군      21,748
# 49      　　　인제군      32,165
# 50      　　　고성군      27,249
# 51      　　　양양군      27,913
# 52        충청북도   1,597,427
# 53      　　　청주시     848,482
# 54      　　　충주시     209,358
# 55      　　　제천시     131,591
# 56      　　　보은군      31,878
# 57      　　　옥천군      50,093
# 58      　　　영동군      45,773
# 59      　　　증평군      36,426
# 60      　　　진천군      85,176
# 61      　　　괴산군      38,122
# 62      　　　음성군      92,197
# 63      　　　단양군      28,331
# 64        충청남도   2,119,257
# 65      　　　당진시     167,092
# 66      　　　천안시     658,486
# 67      　　　공주시     103,145
# 68      　　　보령시      98,408
# 69      　　　아산시     324,580
# 70      　　　서산시     176,645
# 71      　　　논산시     114,483
# 72      　　　계룡시      43,331
# 73      　　　금산군      50,477
# 74      　　　부여군      63,774
# 75      　　　서천군      50,745
# 76      　　　청양군      30,440
# 77      　　　홍성군      99,324
# 78      　　　예산군      76,801
# 79      　　　태안군      61,526
# 80        전라북도   1,786,855
# 81      　　　전주시     657,269
# 82      　　　군산시     265,304
# 83      　　　익산시     278,113
# 84      　　　정읍시     106,487
# 85      　　　남원시      79,431
# 86      　　　김제시      80,913
# 87      　　　완주군      91,142
# 88      　　　진안군      24,987
# 89      　　　무주군      23,748
# 90      　　　장수군      21,695
# 91      　　　임실군      26,730
# 92      　　　순창군      26,855
# 93      　　　고창군      53,386
# 94      　　　부안군      50,795
# 95        전라남도   1,832,803
# 96      　　　목포시     218,589
# 97      　　　여수시     276,762
# 98      　　　순천시     281,436
# 99      　　　나주시     116,726
# 100     　　　광양시     150,531
# 101     　　　담양군      46,180
# 102     　　　곡성군      27,535
# 103     　　　구례군      25,235
# 104     　　　고흥군      62,762
# 105     　　　보성군      39,375
# 106     　　　화순군      62,624
# 107     　　　장흥군      36,547
# 108     　　　강진군      33,753
# 109     　　　해남군      67,166
# 110     　　　영암군      52,937
# 111     　　　무안군      91,107
# 112     　　　함평군      31,274
# 113     　　　영광군      51,985
# 114     　　　장성군      43,365
# 115     　　　완도군      48,631
# 116     　　　진도군      30,066
# 117     　　　신안군      38,217
# 118       경상북도   2,626,609
# 119     　　　포항시     503,852
# 120     　　　경주시     251,889
# 121     　　　김천시     140,239
# 122     　　　안동시     156,972
# 123     　　　구미시     412,581
# 124     　　　영주시     101,942
# 125     　　　영천시     101,888
# 126     　　　상주시      95,566
# 127     　　　문경시      71,154
# 128     　　　경산시     268,369
# 129     　　　군위군      22,945
# 130     　　　의성군      50,632
# 131     　　　청송군      24,539
# 132     　　　영양군      16,320
# 133     　　　영덕군      35,314
# 134     　　　청도군      41,891
# 135     　　　고령군      30,626
# 136     　　　성주군      42,842
# 137     　　　칠곡군     113,822
# 138     　　　예천군      55,739
# 139     　　　봉화군      30,762
# 140     　　　울진군      47,858
# 141     　　　울릉군       8,867
# 142       경상남도   3,314,183
# 143     　　　창원시   1,032,741
# 144     　　　진주시     347,097
# 145     　　　통영시     125,383
# 146     　　　사천시     109,953
# 147     　　　김해시     537,673
# 148     　　　밀양시     103,525
# 149     　　　거제시     241,216
# 150     　　　양산시     354,726
# 151     　　　의령군      26,322
# 152     　　　함안군      62,547
# 153     　　　창녕군      60,129
# 154     　　　고성군      50,478
# 155     　　　남해군      42,266
# 156     　　　하동군      43,449
# 157     　　　산청군      34,360
# 158     　　　함양군      38,310
# 159     　　　거창군      61,073
# 160     　　　합천군      42,935

# %%
# 데이터 타입 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 1 to 160
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   행정구역(시군구)별  160 non-null    object
#  1   2021        160 non-null    object
# dtypes: object(2)
# memory usage: 2.6+ KB

# %%
# 실수형 변환 전 문자열(,) 제거
df['2021'] = df['2021'].str.replace(",", "")
df.head()
# Out:
#   행정구역(시군구)별      2021
# 1        경기도  13565450
# 2     　　　수원시   1183714
# 3     　　　성남시    930948
# 4    　　　의정부시    463661
# 5     　　　안양시    547178

# %%
# 500,000 이상 이하 구분을 위해 2022.07열의 데이터 타입을 실수형으로 변환
df = df.astype({'2021':'float64'})

# %%
# 500000 이하인 행만 추출
df = df[df['2021']<=500000]

# %%
# 인덱스 재정렬
df.reset_index(drop=True, inplace=True)
df
# Out:
#     행정구역(시군구)별      2021
# 0      　　　의정부시  463661.0
# 1       　　　광명시  292893.0
# 2      　　　동두천시   93592.0
# 3       　　　과천시   73345.0
# 4       　　　구리시  191948.0
# 5       　　　오산시  229983.0
# 6       　　　군포시  268535.0
# 7       　　　의왕시  163356.0
# 8       　　　하남시  320087.0
# 64      　　　정읍시  106487.0
# 65      　　　남원시   79431.0
# 66      　　　김제시   80913.0
# 67      　　　완주군   91142.0
# 68      　　　진안군   24987.0
# 69      　　　무주군   23748.0
# 70      　　　장수군   21695.0
# 71      　　　임실군   26730.0
# 72      　　　순창군   26855.0
# 73      　　　고창군   53386.0
# 74      　　　부안군   50795.0
# 75      　　　목포시  218589.0
# 76      　　　여수시  276762.0
# 77      　　　순천시  281436.0
# 78      　　　나주시  116726.0
# 79      　　　광양시  150531.0
# 80      　　　담양군   46180.0
# 81      　　　곡성군   27535.0
# 82      　　　구례군   25235.0
# 83      　　　고흥군   62762.0
# 84      　　　보성군   39375.0
# 85      　　　화순군   62624.0
# 86      　　　장흥군   36547.0
# 87      　　　강진군   33753.0
# 88      　　　해남군   67166.0
# 89      　　　영암군   52937.0
# 90      　　　무안군   91107.0
# 91      　　　함평군   31274.0
# 92      　　　영광군   51985.0
# 93      　　　장성군   43365.0
# 94      　　　완도군   48631.0
# 95      　　　진도군   30066.0
# 96      　　　신안군   38217.0
# 97      　　　경주시  251889.0
# 98      　　　김천시  140239.0
# 99      　　　안동시  156972.0
# 100     　　　구미시  412581.0
# 101     　　　영주시  101942.0
# 102     　　　영천시  101888.0
# 103     　　　상주시   95566.0
# 104     　　　문경시   71154.0
# 105     　　　경산시  268369.0
# 106     　　　군위군   22945.0
# 107     　　　의성군   50632.0
# 108     　　　청송군   24539.0
# 109     　　　영양군   16320.0
# 110     　　　영덕군   35314.0
# 111     　　　청도군   41891.0
# 112     　　　고령군   30626.0
# 113     　　　성주군   42842.0
# 114     　　　칠곡군  113822.0
# 115     　　　예천군   55739.0
# 116     　　　봉화군   30762.0
# 117     　　　울진군   47858.0
# 118     　　　울릉군    8867.0
# 119     　　　진주시  347097.0
# 120     　　　통영시  125383.0
# 121     　　　사천시  109953.0
# 122     　　　밀양시  103525.0
# 123     　　　거제시  241216.0
# 124     　　　양산시  354726.0
# 125     　　　의령군   26322.0
# 126     　　　함안군   62547.0
# 127     　　　창녕군   60129.0
# 128     　　　고성군   50478.0
# 129     　　　남해군   42266.0
# 130     　　　하동군   43449.0
# 131     　　　산청군   34360.0
# 132     　　　함양군   38310.0
# 133     　　　거창군   61073.0
# 134     　　　합천군   42935.0

# %%
#도 기준 자르기
gyeonggi = df[:19]
gangwon = df[20:37]
chungbook = df[38:47]
chungnam = df[48:61]
junbook = df[62:74]
junnam = df[75:96]
gyeongbook = df[97:118]
gyeongnam = df[119:]

# %%
# 전체 행 보이게
pd.set_option('display.max_rows',None)
# pd.options.display.max_rows = 60

# %% [markdown]
# ## 인구수 기준 데이터 처리 완료: df

# %%
df
# Out:
#     행정구역(시군구)별      2021
# 0      　　　의정부시  463661.0
# 1       　　　광명시  292893.0
# 2      　　　동두천시   93592.0
# 3       　　　과천시   73345.0
# 4       　　　구리시  191948.0
# 5       　　　오산시  229983.0
# 6       　　　군포시  268535.0
# 7       　　　의왕시  163356.0
# 8       　　　하남시  320087.0
# 9       　　　파주시  483245.0
# 10      　　　이천시  223177.0
# 11      　　　안성시  189534.0
# 12      　　　김포시  486508.0
# 13      　　　광주시  387289.0
# 113     　　　성주군   42842.0
# 114     　　　칠곡군  113822.0
# 115     　　　예천군   55739.0
# 116     　　　봉화군   30762.0
# 117     　　　울진군   47858.0
# 118     　　　울릉군    8867.0
# 119     　　　진주시  347097.0
# 120     　　　통영시  125383.0
# 121     　　　사천시  109953.0
# 122     　　　밀양시  103525.0
# 123     　　　거제시  241216.0
# 124     　　　양산시  354726.0
# 125     　　　의령군   26322.0
# 126     　　　함안군   62547.0
# 127     　　　창녕군   60129.0
# 128     　　　고성군   50478.0
# 129     　　　남해군   42266.0
# 130     　　　하동군   43449.0
# 131     　　　산청군   34360.0
# 132     　　　함양군   38310.0
# 133     　　　거창군   61073.0
# 134     　　　합천군   42935.0

# %%
df.to_csv('city_list.csv',encoding='cp949')

# %% [markdown]
# ## 지역명만: city_df

# %%
# 지역명만 뽑아내서 데이터프레임화
df['행정구역(시군구)별'].to_list()
city_list = df['행정구역(시군구)별'].str.replace("\u3000\u3000\u3000","")
city_df = pd.DataFrame(city_list)
city_df.head()
# Out:
#   행정구역(시군구)별
# 0       의정부시
# 1        광명시
# 2       동두천시
# 3        과천시
# 4        구리시

# %% [markdown]
# # 2차

# %% [markdown]
# ## 1. 방문자수 데이터

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# 시별 이름 추출
gyeongnam1 = gyeongnam['행정구역(시군구)별'].str.replace("\u3000\u3000\u3000","").to_list()
gyeongbook1 = gyeongbook['행정구역(시군구)별'].str.replace("\u3000\u3000\u3000","").to_list()
junnam1 = junnam['행정구역(시군구)별'].str.replace("\u3000\u3000\u3000","").to_list()
junbook1 = junbook['행정구역(시군구)별'].str.replace("\u3000\u3000\u3000","").to_list()
gyeonggi1 = gyeonggi['행정구역(시군구)별'].str.replace("\u3000\u3000\u3000","").to_list()
gangwon1 = gangwon['행정구역(시군구)별'].str.replace("\u3000\u3000\u3000","").to_list()
chungbook1 = chungbook['행정구역(시군구)별'].str.replace("\u3000\u3000\u3000","").to_list()
chungnam1 = chungnam['행정구역(시군구)별'].str.replace("\u3000\u3000\u3000","").to_list()

# %%
f = pd.read_csv("C:\\Users\\82108\\DataLab_data\\경상남도\\거제시\\SNS언급량\\2019.csv", encoding="cp949")
f.columns
# Out:
# Index(['기준연월', '지역명', '검색량(건)'], dtype='object')

# %%
#
city = {"경기도":gyeonggi1, "경상남도":gyeongnam1, "경상북도":gyeongbook1, "전라남도":junnam1, "전라북도":junbook1,
       "충청남도":chungnam1, "충청북도":chungbook1, "강원도":gangwon1}
city
# Out:
# {'경기도': ['의정부시',
#   '광명시',
#   '동두천시',
#   '과천시',
#   '구리시',
#   '오산시',
#   '군포시',
#   '의왕시',
#   '하남시',
#   '파주시',
#   '이천시',
#   '안성시',
#   '김포시',
#   '광주시',
#   '양주시',
#   '포천시',
#   '여주시',
#   '연천군',
#   '가평군'],
#  '경상남도': ['진주시',
#   '통영시',
#   '사천시',
#   '밀양시',
#   '거제시',
#   '양산시',
#   '의령군',
#   '함안군',
#   '창녕군',
#   '고성군',
#   '남해군',
#   '하동군',
#   '산청군',
#   '함양군',
#   '거창군',
#   '합천군'],
#  '경상북도': ['경주시',
#   '김천시',
#   '안동시',
#   '구미시',
#   '영주시',
#   '영천시',
#   '상주시',
#   '문경시',
#   '경산시',
#   '군위군',
#   '의성군',
#   '청송군',
#   '영양군',
#   '영덕군',
#   '청도군',
#   '고령군',
#   '성주군',
#   '칠곡군',
#   '예천군',
#   '봉화군',
#   '울진군'],
#  '전라남도': ['목포시',
#   '여수시',
#   '순천시',
#   '나주시',
#   '광양시',
#   '담양군',
#   '곡성군',
#   '구례군',
#   '고흥군',
#   '보성군',
#   '화순군',
#   '장흥군',
#   '강진군',
#   '해남군',
#   '영암군',
#   '무안군',
#   '함평군',
#   '영광군',
#   '장성군',
#   '완도군',
#   '진도군'],
#  '전라북도': ['군산시',
#   '익산시',
#   '정읍시',
#   '남원시',
#   '김제시',
#   '완주군',
#   '진안군',
#   '무주군',
#   '장수군',
#   '임실군',
#   '순창군',
#   '고창군'],
#  '충청남도': ['당진시',
#   '공주시',
#   '보령시',
#   '아산시',
#   '서산시',
#   '논산시',
#   '계룡시',
#   '금산군',
#   '부여군',
#   '서천군',
#   '청양군',
#   '홍성군',
#   '예산군'],
#  '충청북도': ['충주시', '제천시', '보은군', '옥천군', '영동군', '증평군', '진천군', '괴산군', '음성군'],
#  '강원도': ['춘천시',
#   '원주시',
#   '강릉시',
#   '동해시',
#   '태백시',
#   '속초시',
#   '삼척시',
#   '홍천군',
#   '횡성군',
#   '영월군',
#   '평창군',
#   '정선군',
#   '철원군',
#   '화천군',
#   '양구군',
#   '인제군',
#   '고성군']}

# %%
folder_name = ["SNS언급량", "방문자수"]

# %%
for do, si in city.items():
    for si_name in si:
        for fn in folder_name:
            f2019 = pd.read_csv("C:\\Users\\82108\\DataLab_data\\"+do+"\\"+si_name+"\\"+fn+"\\2019.csv",encoding='cp949')
            f2020 = pd.read_csv("C:\\Users\\82108\\DataLab_data\\"+do+"\\"+si_name+"\\"+fn+"\\2020.csv",encoding='cp949')
            f2021 = pd.read_csv("C:\\Users\\82108\\DataLab_data\\"+do+"\\"+si_name+"\\"+fn+"\\2021.csv",encoding='cp949')
            f2022 = pd.read_csv("C:\\Users\\82108\\DataLab_data\\"+do+"\\"+si_name+"\\"+fn+"\\2022.csv",encoding='cp949')
            
            f2019.drop(['지역명'], axis=1, inplace=True)
            f2020.drop(['지역명'], axis=1, inplace=True)
            f2021.drop(['지역명'], axis=1, inplace=True)
            f2022.drop(['지역명'], axis=1, inplace=True)
            
            result = pd.concat([f2019, f2020, f2021, f2022], ignore_index=True)

            result.to_csv('C:\\Users\\82108\\result\\' + do + '\\' + fn + '\\' + si_name +".csv", encoding='cp949', index=False)

# %%
file = pd.read_csv("C:\\Users\\82108\\result_data\\강원도\\SNS언급량\\강릉시.csv", encoding='cp949')
plt.plot(file['기준연월'], file['검색량(건)'])
plt.savefig('C:\\Users\\82108\\image.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-9b6a9b4cfd02> in <module>
#       1 file = pd.read_csv("C:\\Users\\82108\\result_data\\강원도\\SNS언급량\\강릉시.csv", encoding='cp949')
# ----> 2 plt.plot(file['기준연월'], file['검색량(건)'])
#       3 plt.savefig('C:\\Users\\82108\\image.png')
#
# NameError: name 'plt' is not defined

# %%
dt_now.strftime('%Y-%m-%d %H:%M:%S')
